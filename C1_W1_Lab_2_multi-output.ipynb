# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 927us/sample - loss: 245.0307 - y1_output_loss: 114.7288 - y2_output_loss: 129.1645 - y1_output_root_mean_squared_error: 10.7331 - y2_output_root_mean_squared_error: 11.3943 - val_loss: 80.3185 - val_y1_output_loss: 26.8391 - val_y2_output_loss: 53.9628 - val_y1_output_root_mean_squared_error: 5.1865 - val_y2_output_root_mean_squared_error: 7.3088
# Epoch 2/500
# 614/614 [==============================] - 0s 142us/sample - loss: 40.4920 - y1_output_loss: 14.0763 - y2_output_loss: 26.0914 - y1_output_root_mean_squared_error: 3.7664 - y2_output_root_mean_squared_error: 5.1290 - val_loss: 22.9740 - val_y1_output_loss: 9.9099 - val_y2_output_loss: 12.7589 - val_y1_output_root_mean_squared_error: 3.1688 - val_y2_output_root_mean_squared_error: 3.5962
# Epoch 3/500
# 614/614 [==============================] - 0s 129us/sample - loss: 27.5799 - y1_output_loss: 10.9163 - y2_output_loss: 16.8689 - y1_output_root_mean_squared_error: 3.2891 - y2_output_root_mean_squared_error: 4.0941 - val_loss: 25.7272 - val_y1_output_loss: 10.4786 - val_y2_output_loss: 15.1573 - val_y1_output_root_mean_squared_error: 3.2345 - val_y2_output_root_mean_squared_error: 3.9071
# Epoch 4/500
# 614/614 [==============================] - 0s 131us/sample - loss: 23.3437 - y1_output_loss: 9.4451 - y2_output_loss: 13.9789 - y1_output_root_mean_squared_error: 3.0754 - y2_output_root_mean_squared_error: 3.7264 - val_loss: 29.3727 - val_y1_output_loss: 9.2583 - val_y2_output_loss: 20.0865 - val_y1_output_root_mean_squared_error: 3.0339 - val_y2_output_root_mean_squared_error: 4.4909
# Epoch 5/500
# 614/614 [==============================] - 0s 132us/sample - loss: 23.5511 - y1_output_loss: 9.6549 - y2_output_loss: 14.2710 - y1_output_root_mean_squared_error: 3.0837 - y2_output_root_mean_squared_error: 3.7473 - val_loss: 24.4943 - val_y1_output_loss: 9.9599 - val_y2_output_loss: 15.5626 - val_y1_output_root_mean_squared_error: 3.1015 - val_y2_output_root_mean_squared_error: 3.8568
# Epoch 6/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.6580 - y1_output_loss: 9.0400 - y2_output_loss: 13.7343 - y1_output_root_mean_squared_error: 2.9846 - y2_output_root_mean_squared_error: 3.7081 - val_loss: 20.8315 - val_y1_output_loss: 9.4298 - val_y2_output_loss: 12.1724 - val_y1_output_root_mean_squared_error: 3.0174 - val_y2_output_root_mean_squared_error: 3.4245
# Epoch 7/500
# 614/614 [==============================] - 0s 126us/sample - loss: 22.9794 - y1_output_loss: 8.8813 - y2_output_loss: 14.0844 - y1_output_root_mean_squared_error: 2.9914 - y2_output_root_mean_squared_error: 3.7458 - val_loss: 38.2626 - val_y1_output_loss: 10.9080 - val_y2_output_loss: 29.8957 - val_y1_output_root_mean_squared_error: 3.2043 - val_y2_output_root_mean_squared_error: 5.2911
# Epoch 8/500
# 614/614 [==============================] - 0s 127us/sample - loss: 23.0799 - y1_output_loss: 9.0092 - y2_output_loss: 14.3381 - y1_output_root_mean_squared_error: 2.9928 - y2_output_root_mean_squared_error: 3.7581 - val_loss: 23.0669 - val_y1_output_loss: 9.8428 - val_y2_output_loss: 14.0960 - val_y1_output_root_mean_squared_error: 3.0888 - val_y2_output_root_mean_squared_error: 3.6778
# Epoch 9/500
# 614/614 [==============================] - 0s 128us/sample - loss: 19.2934 - y1_output_loss: 7.9721 - y2_output_loss: 11.3639 - y1_output_root_mean_squared_error: 2.8053 - y2_output_root_mean_squared_error: 3.3799 - val_loss: 34.6399 - val_y1_output_loss: 15.3835 - val_y2_output_loss: 21.6598 - val_y1_output_root_mean_squared_error: 3.7973 - val_y2_output_root_mean_squared_error: 4.4967
# Epoch 10/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.6979 - y1_output_loss: 8.0859 - y2_output_loss: 12.7396 - y1_output_root_mean_squared_error: 2.8520 - y2_output_root_mean_squared_error: 3.5446 - val_loss: 35.1934 - val_y1_output_loss: 9.5766 - val_y2_output_loss: 25.6108 - val_y1_output_root_mean_squared_error: 3.0844 - val_y2_output_root_mean_squared_error: 5.0676
# Epoch 11/500
# 614/614 [==============================] - 0s 127us/sample - loss: 18.7483 - y1_output_loss: 7.4886 - y2_output_loss: 11.2805 - y1_output_root_mean_squared_error: 2.7343 - y2_output_root_mean_squared_error: 3.3574 - val_loss: 24.2515 - val_y1_output_loss: 9.3513 - val_y2_output_loss: 15.2433 - val_y1_output_root_mean_squared_error: 3.0325 - val_y2_output_root_mean_squared_error: 3.8801
# Epoch 12/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.8915 - y1_output_loss: 8.1305 - y2_output_loss: 12.5997 - y1_output_root_mean_squared_error: 2.8636 - y2_output_root_mean_squared_error: 3.5625 - val_loss: 19.2516 - val_y1_output_loss: 8.0731 - val_y2_output_loss: 11.5788 - val_y1_output_root_mean_squared_error: 2.8076 - val_y2_output_root_mean_squared_error: 3.3718
# Epoch 13/500
# 614/614 [==============================] - 0s 126us/sample - loss: 22.8436 - y1_output_loss: 8.2142 - y2_output_loss: 14.5629 - y1_output_root_mean_squared_error: 2.8757 - y2_output_root_mean_squared_error: 3.8176 - val_loss: 44.4728 - val_y1_output_loss: 11.0373 - val_y2_output_loss: 33.9795 - val_y1_output_root_mean_squared_error: 3.2883 - val_y2_output_root_mean_squared_error: 5.8017
# Epoch 14/500
# 614/614 [==============================] - 0s 127us/sample - loss: 17.5372 - y1_output_loss: 7.1608 - y2_output_loss: 10.2856 - y1_output_root_mean_squared_error: 2.6853 - y2_output_root_mean_squared_error: 3.2135 - val_loss: 18.3280 - val_y1_output_loss: 8.9250 - val_y2_output_loss: 10.4289 - val_y1_output_root_mean_squared_error: 2.8830 - val_y2_output_root_mean_squared_error: 3.1648
# Epoch 15/500
# 614/614 [==============================] - 0s 126us/sample - loss: 21.6316 - y1_output_loss: 7.9620 - y2_output_loss: 14.1365 - y1_output_root_mean_squared_error: 2.7958 - y2_output_root_mean_squared_error: 3.7169 - val_loss: 44.8525 - val_y1_output_loss: 13.6395 - val_y2_output_loss: 31.1068 - val_y1_output_root_mean_squared_error: 3.7077 - val_y2_output_root_mean_squared_error: 5.5772
# Epoch 16/500
# 614/614 [==============================] - 0s 126us/sample - loss: 20.0466 - y1_output_loss: 7.4083 - y2_output_loss: 12.5582 - y1_output_root_mean_squared_error: 2.7315 - y2_output_root_mean_squared_error: 3.5476 - val_loss: 16.6403 - val_y1_output_loss: 7.4238 - val_y2_output_loss: 9.9617 - val_y1_output_root_mean_squared_error: 2.6592 - val_y2_output_root_mean_squared_error: 3.0934
# Epoch 17/500
# 614/614 [==============================] - 0s 132us/sample - loss: 23.2965 - y1_output_loss: 8.0057 - y2_output_loss: 15.2355 - y1_output_root_mean_squared_error: 2.8346 - y2_output_root_mean_squared_error: 3.9066 - val_loss: 19.1912 - val_y1_output_loss: 9.0187 - val_y2_output_loss: 11.2861 - val_y1_output_root_mean_squared_error: 2.9203 - val_y2_output_root_mean_squared_error: 3.2654
# Epoch 18/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.8616 - y1_output_loss: 6.7233 - y2_output_loss: 11.1433 - y1_output_root_mean_squared_error: 2.5927 - y2_output_root_mean_squared_error: 3.3376 - val_loss: 17.2703 - val_y1_output_loss: 7.8584 - val_y2_output_loss: 10.6361 - val_y1_output_root_mean_squared_error: 2.7115 - val_y2_output_root_mean_squared_error: 3.1493
# Epoch 19/500
# 614/614 [==============================] - 0s 129us/sample - loss: 17.7483 - y1_output_loss: 6.7083 - y2_output_loss: 10.9353 - y1_output_root_mean_squared_error: 2.6020 - y2_output_root_mean_squared_error: 3.3133 - val_loss: 15.8051 - val_y1_output_loss: 7.1760 - val_y2_output_loss: 9.6501 - val_y1_output_root_mean_squared_error: 2.5796 - val_y2_output_root_mean_squared_error: 3.0250
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.1098 - y1_output_loss: 6.2324 - y2_output_loss: 9.7425 - y1_output_root_mean_squared_error: 2.5074 - y2_output_root_mean_squared_error: 3.1341 - val_loss: 19.9291 - val_y1_output_loss: 8.7742 - val_y2_output_loss: 13.1469 - val_y1_output_root_mean_squared_error: 2.8293 - val_y2_output_root_mean_squared_error: 3.4532
# Epoch 21/500
# 614/614 [==============================] - 0s 133us/sample - loss: 16.0469 - y1_output_loss: 6.0889 - y2_output_loss: 10.1142 - y1_output_root_mean_squared_error: 2.4602 - y2_output_root_mean_squared_error: 3.1614 - val_loss: 21.6538 - val_y1_output_loss: 7.5903 - val_y2_output_loss: 15.9892 - val_y1_output_root_mean_squared_error: 2.6550 - val_y2_output_root_mean_squared_error: 3.8216
# Epoch 22/500
# 614/614 [==============================] - 0s 130us/sample - loss: 18.9395 - y1_output_loss: 6.4566 - y2_output_loss: 12.3307 - y1_output_root_mean_squared_error: 2.5514 - y2_output_root_mean_squared_error: 3.5256 - val_loss: 18.1851 - val_y1_output_loss: 8.5062 - val_y2_output_loss: 11.3403 - val_y1_output_root_mean_squared_error: 2.7925 - val_y2_output_root_mean_squared_error: 3.2229
# Epoch 23/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.7926 - y1_output_loss: 6.0105 - y2_output_loss: 9.7016 - y1_output_root_mean_squared_error: 2.4591 - y2_output_root_mean_squared_error: 3.1218 - val_loss: 14.5336 - val_y1_output_loss: 6.1312 - val_y2_output_loss: 9.2222 - val_y1_output_root_mean_squared_error: 2.4025 - val_y2_output_root_mean_squared_error: 2.9600
# Epoch 24/500
# 614/614 [==============================] - 0s 127us/sample - loss: 13.1123 - y1_output_loss: 5.2682 - y2_output_loss: 8.0094 - y1_output_root_mean_squared_error: 2.2967 - y2_output_root_mean_squared_error: 2.7996 - val_loss: 24.0669 - val_y1_output_loss: 8.1641 - val_y2_output_loss: 18.0255 - val_y1_output_root_mean_squared_error: 2.7317 - val_y2_output_root_mean_squared_error: 4.0749
# Epoch 25/500
# 614/614 [==============================] - 0s 133us/sample - loss: 16.7265 - y1_output_loss: 5.6678 - y2_output_loss: 11.1280 - y1_output_root_mean_squared_error: 2.3791 - y2_output_root_mean_squared_error: 3.3266 - val_loss: 38.6047 - val_y1_output_loss: 11.5480 - val_y2_output_loss: 30.2947 - val_y1_output_root_mean_squared_error: 3.2445 - val_y2_output_root_mean_squared_error: 5.2988
# Epoch 26/500
# 614/614 [==============================] - 0s 129us/sample - loss: 16.1266 - y1_output_loss: 5.6835 - y2_output_loss: 10.4118 - y1_output_root_mean_squared_error: 2.3888 - y2_output_root_mean_squared_error: 3.2280 - val_loss: 13.9239 - val_y1_output_loss: 6.3371 - val_y2_output_loss: 8.7422 - val_y1_output_root_mean_squared_error: 2.4243 - val_y2_output_root_mean_squared_error: 2.8366
# Epoch 27/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.1431 - y1_output_loss: 4.8885 - y2_output_loss: 8.2539 - y1_output_root_mean_squared_error: 2.2172 - y2_output_root_mean_squared_error: 2.8683 - val_loss: 25.2941 - val_y1_output_loss: 9.1775 - val_y2_output_loss: 18.4427 - val_y1_output_root_mean_squared_error: 2.8904 - val_y2_output_root_mean_squared_error: 4.1158
# Epoch 28/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.3118 - y1_output_loss: 4.6470 - y2_output_loss: 8.6083 - y1_output_root_mean_squared_error: 2.1578 - y2_output_root_mean_squared_error: 2.9421 - val_loss: 14.1002 - val_y1_output_loss: 7.3048 - val_y2_output_loss: 8.0638 - val_y1_output_root_mean_squared_error: 2.5785 - val_y2_output_root_mean_squared_error: 2.7297
# Epoch 29/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.8718 - y1_output_loss: 4.6123 - y2_output_loss: 7.1690 - y1_output_root_mean_squared_error: 2.1552 - y2_output_root_mean_squared_error: 2.6883 - val_loss: 12.1358 - val_y1_output_loss: 5.4909 - val_y2_output_loss: 7.8234 - val_y1_output_root_mean_squared_error: 2.2317 - val_y2_output_root_mean_squared_error: 2.6750
# Epoch 30/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.2862 - y1_output_loss: 4.4524 - y2_output_loss: 7.7913 - y1_output_root_mean_squared_error: 2.1059 - y2_output_root_mean_squared_error: 2.8020 - val_loss: 13.9022 - val_y1_output_loss: 7.2327 - val_y2_output_loss: 8.1468 - val_y1_output_root_mean_squared_error: 2.5566 - val_y2_output_root_mean_squared_error: 2.7140
# Epoch 31/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.1257 - y1_output_loss: 4.1434 - y2_output_loss: 6.9022 - y1_output_root_mean_squared_error: 2.0429 - y2_output_root_mean_squared_error: 2.6367 - val_loss: 12.2969 - val_y1_output_loss: 4.9409 - val_y2_output_loss: 8.2367 - val_y1_output_root_mean_squared_error: 2.1268 - val_y2_output_root_mean_squared_error: 2.7881
# Epoch 32/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.3813 - y1_output_loss: 4.3443 - y2_output_loss: 7.9375 - y1_output_root_mean_squared_error: 2.0934 - y2_output_root_mean_squared_error: 2.8283 - val_loss: 12.1366 - val_y1_output_loss: 5.3222 - val_y2_output_loss: 7.5534 - val_y1_output_root_mean_squared_error: 2.2469 - val_y2_output_root_mean_squared_error: 2.6623
# Epoch 33/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.4276 - y1_output_loss: 4.5807 - y2_output_loss: 8.1156 - y1_output_root_mean_squared_error: 2.1055 - y2_output_root_mean_squared_error: 2.8274 - val_loss: 40.0993 - val_y1_output_loss: 11.8040 - val_y2_output_loss: 29.0284 - val_y1_output_root_mean_squared_error: 3.4088 - val_y2_output_root_mean_squared_error: 5.3366
# Epoch 34/500
# 614/614 [==============================] - 0s 134us/sample - loss: 17.6732 - y1_output_loss: 5.5646 - y2_output_loss: 12.0340 - y1_output_root_mean_squared_error: 2.3674 - y2_output_root_mean_squared_error: 3.4740 - val_loss: 15.3373 - val_y1_output_loss: 6.0899 - val_y2_output_loss: 10.6402 - val_y1_output_root_mean_squared_error: 2.3621 - val_y2_output_root_mean_squared_error: 3.1237
# Epoch 35/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.3483 - y1_output_loss: 3.8603 - y2_output_loss: 7.4536 - y1_output_root_mean_squared_error: 1.9565 - y2_output_root_mean_squared_error: 2.7423 - val_loss: 14.1409 - val_y1_output_loss: 5.7290 - val_y2_output_loss: 8.8973 - val_y1_output_root_mean_squared_error: 2.3566 - val_y2_output_root_mean_squared_error: 2.9304
# Epoch 36/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.6813 - y1_output_loss: 3.4299 - y2_output_loss: 6.3109 - y1_output_root_mean_squared_error: 1.8322 - y2_output_root_mean_squared_error: 2.5149 - val_loss: 14.5091 - val_y1_output_loss: 4.9523 - val_y2_output_loss: 10.2546 - val_y1_output_root_mean_squared_error: 2.1620 - val_y2_output_root_mean_squared_error: 3.1361
# Epoch 37/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.9033 - y1_output_loss: 2.9762 - y2_output_loss: 5.9475 - y1_output_root_mean_squared_error: 1.7309 - y2_output_root_mean_squared_error: 2.4305 - val_loss: 13.6118 - val_y1_output_loss: 5.0332 - val_y2_output_loss: 9.8803 - val_y1_output_root_mean_squared_error: 2.1314 - val_y2_output_root_mean_squared_error: 3.0114
# Epoch 38/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.9608 - y1_output_loss: 3.5385 - y2_output_loss: 6.3543 - y1_output_root_mean_squared_error: 1.8836 - y2_output_root_mean_squared_error: 2.5324 - val_loss: 9.4317 - val_y1_output_loss: 3.8022 - val_y2_output_loss: 6.3495 - val_y1_output_root_mean_squared_error: 1.8667 - val_y2_output_root_mean_squared_error: 2.4387
# Epoch 39/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.1798 - y1_output_loss: 2.8972 - y2_output_loss: 5.2255 - y1_output_root_mean_squared_error: 1.7075 - y2_output_root_mean_squared_error: 2.2944 - val_loss: 8.8240 - val_y1_output_loss: 3.8980 - val_y2_output_loss: 5.6850 - val_y1_output_root_mean_squared_error: 1.8997 - val_y2_output_root_mean_squared_error: 2.2837
# Epoch 40/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.2385 - y1_output_loss: 2.8414 - y2_output_loss: 5.4738 - y1_output_root_mean_squared_error: 1.6894 - y2_output_root_mean_squared_error: 2.3204 - val_loss: 9.3977 - val_y1_output_loss: 3.8683 - val_y2_output_loss: 6.4277 - val_y1_output_root_mean_squared_error: 1.8743 - val_y2_output_root_mean_squared_error: 2.4259
# Epoch 41/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.7105 - y1_output_loss: 2.8026 - y2_output_loss: 5.8772 - y1_output_root_mean_squared_error: 1.6814 - y2_output_root_mean_squared_error: 2.4256 - val_loss: 10.1508 - val_y1_output_loss: 3.8851 - val_y2_output_loss: 7.3066 - val_y1_output_root_mean_squared_error: 1.8761 - val_y2_output_root_mean_squared_error: 2.5751
# Epoch 42/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.1558 - y1_output_loss: 2.8429 - y2_output_loss: 6.2364 - y1_output_root_mean_squared_error: 1.6934 - y2_output_root_mean_squared_error: 2.5076 - val_loss: 9.9421 - val_y1_output_loss: 4.2510 - val_y2_output_loss: 6.6994 - val_y1_output_root_mean_squared_error: 1.9675 - val_y2_output_root_mean_squared_error: 2.4640
# Epoch 43/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.0960 - y1_output_loss: 2.6192 - y2_output_loss: 5.4160 - y1_output_root_mean_squared_error: 1.6236 - y2_output_root_mean_squared_error: 2.3367 - val_loss: 8.2339 - val_y1_output_loss: 3.4371 - val_y2_output_loss: 5.3897 - val_y1_output_root_mean_squared_error: 1.7908 - val_y2_output_root_mean_squared_error: 2.2421
# Epoch 44/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.2701 - y1_output_loss: 2.6849 - y2_output_loss: 5.6392 - y1_output_root_mean_squared_error: 1.6315 - y2_output_root_mean_squared_error: 2.3682 - val_loss: 7.8746 - val_y1_output_loss: 3.2975 - val_y2_output_loss: 5.2473 - val_y1_output_root_mean_squared_error: 1.7415 - val_y2_output_root_mean_squared_error: 2.2004
# Epoch 45/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.0676 - y1_output_loss: 2.5373 - y2_output_loss: 5.5781 - y1_output_root_mean_squared_error: 1.5854 - y2_output_root_mean_squared_error: 2.3567 - val_loss: 7.3855 - val_y1_output_loss: 3.0905 - val_y2_output_loss: 4.9448 - val_y1_output_root_mean_squared_error: 1.6871 - val_y2_output_root_mean_squared_error: 2.1305
# Epoch 46/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.3011 - y1_output_loss: 2.3925 - y2_output_loss: 4.8569 - y1_output_root_mean_squared_error: 1.5519 - y2_output_root_mean_squared_error: 2.2120 - val_loss: 7.9304 - val_y1_output_loss: 3.6168 - val_y2_output_loss: 5.0724 - val_y1_output_root_mean_squared_error: 1.8085 - val_y2_output_root_mean_squared_error: 2.1586
# Epoch 47/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.1582 - y1_output_loss: 2.5193 - y2_output_loss: 5.6900 - y1_output_root_mean_squared_error: 1.5864 - y2_output_root_mean_squared_error: 2.3752 - val_loss: 12.0807 - val_y1_output_loss: 4.2701 - val_y2_output_loss: 8.7544 - val_y1_output_root_mean_squared_error: 1.9718 - val_y2_output_root_mean_squared_error: 2.8623
# Epoch 48/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.0693 - y1_output_loss: 2.3158 - y2_output_loss: 4.6908 - y1_output_root_mean_squared_error: 1.5275 - y2_output_root_mean_squared_error: 2.1762 - val_loss: 6.5928 - val_y1_output_loss: 2.4444 - val_y2_output_loss: 4.5118 - val_y1_output_root_mean_squared_error: 1.5170 - val_y2_output_root_mean_squared_error: 2.0716
# Epoch 49/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.1312 - y1_output_loss: 1.9254 - y2_output_loss: 4.2757 - y1_output_root_mean_squared_error: 1.3866 - y2_output_root_mean_squared_error: 2.0515 - val_loss: 17.0982 - val_y1_output_loss: 5.0198 - val_y2_output_loss: 12.5232 - val_y1_output_root_mean_squared_error: 2.1990 - val_y2_output_root_mean_squared_error: 3.5018
# Epoch 50/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.6072 - y1_output_loss: 2.5850 - y2_output_loss: 6.0351 - y1_output_root_mean_squared_error: 1.6133 - y2_output_root_mean_squared_error: 2.4504 - val_loss: 7.8570 - val_y1_output_loss: 2.4888 - val_y2_output_loss: 5.9458 - val_y1_output_root_mean_squared_error: 1.5140 - val_y2_output_root_mean_squared_error: 2.3590
# Epoch 51/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.6914 - y1_output_loss: 1.9188 - y2_output_loss: 4.7318 - y1_output_root_mean_squared_error: 1.3896 - y2_output_root_mean_squared_error: 2.1818 - val_loss: 9.6348 - val_y1_output_loss: 2.8419 - val_y2_output_loss: 7.4923 - val_y1_output_root_mean_squared_error: 1.6131 - val_y2_output_root_mean_squared_error: 2.6519
# Epoch 52/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.0804 - y1_output_loss: 1.9841 - y2_output_loss: 5.0673 - y1_output_root_mean_squared_error: 1.4081 - y2_output_root_mean_squared_error: 2.2578 - val_loss: 15.6887 - val_y1_output_loss: 6.1117 - val_y2_output_loss: 10.6832 - val_y1_output_root_mean_squared_error: 2.3766 - val_y2_output_root_mean_squared_error: 3.1686
# Epoch 53/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.9436 - y1_output_loss: 2.1907 - y2_output_loss: 4.6970 - y1_output_root_mean_squared_error: 1.4851 - y2_output_root_mean_squared_error: 2.1767 - val_loss: 7.0061 - val_y1_output_loss: 2.6475 - val_y2_output_loss: 5.0172 - val_y1_output_root_mean_squared_error: 1.5456 - val_y2_output_root_mean_squared_error: 2.1488
# Epoch 54/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.6653 - y1_output_loss: 1.9129 - y2_output_loss: 4.7113 - y1_output_root_mean_squared_error: 1.3847 - y2_output_root_mean_squared_error: 2.1789 - val_loss: 7.4212 - val_y1_output_loss: 2.7516 - val_y2_output_loss: 4.9879 - val_y1_output_root_mean_squared_error: 1.6261 - val_y2_output_root_mean_squared_error: 2.1856
# Epoch 55/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.7056 - y1_output_loss: 2.0075 - y2_output_loss: 4.6532 - y1_output_root_mean_squared_error: 1.4186 - y2_output_root_mean_squared_error: 2.1663 - val_loss: 7.0135 - val_y1_output_loss: 2.3657 - val_y2_output_loss: 5.2911 - val_y1_output_root_mean_squared_error: 1.4583 - val_y2_output_root_mean_squared_error: 2.2106
# Epoch 56/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.6051 - y1_output_loss: 2.4364 - y2_output_loss: 6.1146 - y1_output_root_mean_squared_error: 1.5661 - y2_output_root_mean_squared_error: 2.4804 - val_loss: 7.2113 - val_y1_output_loss: 2.6446 - val_y2_output_loss: 5.1603 - val_y1_output_root_mean_squared_error: 1.5497 - val_y2_output_root_mean_squared_error: 2.1931
# Epoch 57/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.1947 - y1_output_loss: 1.4457 - y2_output_loss: 3.7437 - y1_output_root_mean_squared_error: 1.2072 - y2_output_root_mean_squared_error: 1.9332 - val_loss: 9.7625 - val_y1_output_loss: 3.0435 - val_y2_output_loss: 7.3345 - val_y1_output_root_mean_squared_error: 1.6746 - val_y2_output_root_mean_squared_error: 2.6378
# Epoch 58/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.3363 - y1_output_loss: 1.7186 - y2_output_loss: 4.5982 - y1_output_root_mean_squared_error: 1.3168 - y2_output_root_mean_squared_error: 2.1453 - val_loss: 5.7078 - val_y1_output_loss: 1.9077 - val_y2_output_loss: 4.0287 - val_y1_output_root_mean_squared_error: 1.3513 - val_y2_output_root_mean_squared_error: 1.9703
# Epoch 59/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.2628 - y1_output_loss: 1.6372 - y2_output_loss: 3.6253 - y1_output_root_mean_squared_error: 1.2784 - y2_output_root_mean_squared_error: 1.9049 - val_loss: 14.5004 - val_y1_output_loss: 4.8812 - val_y2_output_loss: 10.0925 - val_y1_output_root_mean_squared_error: 2.1730 - val_y2_output_root_mean_squared_error: 3.1271
# Epoch 60/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.6782 - y1_output_loss: 1.5488 - y2_output_loss: 4.0907 - y1_output_root_mean_squared_error: 1.2447 - y2_output_root_mean_squared_error: 2.0320 - val_loss: 6.4851 - val_y1_output_loss: 1.6686 - val_y2_output_loss: 5.0981 - val_y1_output_root_mean_squared_error: 1.2383 - val_y2_output_root_mean_squared_error: 2.2252
# Epoch 61/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.6242 - y1_output_loss: 1.2226 - y2_output_loss: 3.3873 - y1_output_root_mean_squared_error: 1.1038 - y2_output_root_mean_squared_error: 1.8455 - val_loss: 4.8601 - val_y1_output_loss: 1.7798 - val_y2_output_loss: 3.4047 - val_y1_output_root_mean_squared_error: 1.2778 - val_y2_output_root_mean_squared_error: 1.7965
# Epoch 62/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.0048 - y1_output_loss: 1.7134 - y2_output_loss: 4.3237 - y1_output_root_mean_squared_error: 1.3024 - y2_output_root_mean_squared_error: 2.0757 - val_loss: 9.3363 - val_y1_output_loss: 2.2220 - val_y2_output_loss: 7.7489 - val_y1_output_root_mean_squared_error: 1.4179 - val_y2_output_root_mean_squared_error: 2.7067
# Epoch 63/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.3260 - y1_output_loss: 1.1509 - y2_output_loss: 3.1562 - y1_output_root_mean_squared_error: 1.0776 - y2_output_root_mean_squared_error: 1.7790 - val_loss: 5.3269 - val_y1_output_loss: 1.6423 - val_y2_output_loss: 4.0555 - val_y1_output_root_mean_squared_error: 1.2341 - val_y2_output_root_mean_squared_error: 1.9503
# Epoch 64/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.7459 - y1_output_loss: 1.5476 - y2_output_loss: 4.2691 - y1_output_root_mean_squared_error: 1.2399 - y2_output_root_mean_squared_error: 2.0515 - val_loss: 13.6694 - val_y1_output_loss: 4.2538 - val_y2_output_loss: 10.1835 - val_y1_output_root_mean_squared_error: 1.9871 - val_y2_output_root_mean_squared_error: 3.1178
# Epoch 65/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.0395 - y1_output_loss: 1.3398 - y2_output_loss: 3.6781 - y1_output_root_mean_squared_error: 1.1611 - y2_output_root_mean_squared_error: 1.9213 - val_loss: 4.6691 - val_y1_output_loss: 1.5247 - val_y2_output_loss: 3.4157 - val_y1_output_root_mean_squared_error: 1.1895 - val_y2_output_root_mean_squared_error: 1.8040
# Epoch 66/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.3980 - y1_output_loss: 1.6550 - y2_output_loss: 4.7516 - y1_output_root_mean_squared_error: 1.2797 - y2_output_root_mean_squared_error: 2.1818 - val_loss: 9.5476 - val_y1_output_loss: 3.1529 - val_y2_output_loss: 6.5981 - val_y1_output_root_mean_squared_error: 1.7536 - val_y2_output_root_mean_squared_error: 2.5441
# Epoch 67/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.4107 - y1_output_loss: 1.4378 - y2_output_loss: 3.9288 - y1_output_root_mean_squared_error: 1.2031 - y2_output_root_mean_squared_error: 1.9908 - val_loss: 5.7535 - val_y1_output_loss: 1.8457 - val_y2_output_loss: 4.2725 - val_y1_output_root_mean_squared_error: 1.3079 - val_y2_output_root_mean_squared_error: 2.0107
# Epoch 68/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.0315 - y1_output_loss: 1.0402 - y2_output_loss: 2.9549 - y1_output_root_mean_squared_error: 1.0244 - y2_output_root_mean_squared_error: 1.7269 - val_loss: 8.9480 - val_y1_output_loss: 3.3759 - val_y2_output_loss: 6.0354 - val_y1_output_root_mean_squared_error: 1.7752 - val_y2_output_root_mean_squared_error: 2.4076
# Epoch 69/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.6441 - y1_output_loss: 1.3070 - y2_output_loss: 3.3031 - y1_output_root_mean_squared_error: 1.1481 - y2_output_root_mean_squared_error: 1.8237 - val_loss: 5.9906 - val_y1_output_loss: 1.2788 - val_y2_output_loss: 5.0507 - val_y1_output_root_mean_squared_error: 1.0856 - val_y2_output_root_mean_squared_error: 2.1937
# Epoch 70/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.8822 - y1_output_loss: 1.3101 - y2_output_loss: 3.5317 - y1_output_root_mean_squared_error: 1.1485 - y2_output_root_mean_squared_error: 1.8876 - val_loss: 5.4140 - val_y1_output_loss: 1.5256 - val_y2_output_loss: 4.0424 - val_y1_output_root_mean_squared_error: 1.2152 - val_y2_output_root_mean_squared_error: 1.9842
# Epoch 71/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.7734 - y1_output_loss: 1.1392 - y2_output_loss: 3.5974 - y1_output_root_mean_squared_error: 1.0689 - y2_output_root_mean_squared_error: 1.9055 - val_loss: 4.4972 - val_y1_output_loss: 1.6793 - val_y2_output_loss: 3.0954 - val_y1_output_root_mean_squared_error: 1.2407 - val_y2_output_root_mean_squared_error: 1.7198
# Epoch 72/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.6358 - y1_output_loss: 1.4320 - y2_output_loss: 4.1977 - y1_output_root_mean_squared_error: 1.2019 - y2_output_root_mean_squared_error: 2.0472 - val_loss: 5.0731 - val_y1_output_loss: 1.8097 - val_y2_output_loss: 3.4851 - val_y1_output_root_mean_squared_error: 1.3199 - val_y2_output_root_mean_squared_error: 1.8251
# Epoch 73/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.7784 - y1_output_loss: 1.2418 - y2_output_loss: 3.5373 - y1_output_root_mean_squared_error: 1.1194 - y2_output_root_mean_squared_error: 1.8776 - val_loss: 5.4827 - val_y1_output_loss: 1.2833 - val_y2_output_loss: 4.3330 - val_y1_output_root_mean_squared_error: 1.1137 - val_y2_output_root_mean_squared_error: 2.0597
# Epoch 74/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.6256 - y1_output_loss: 1.4067 - y2_output_loss: 4.2723 - y1_output_root_mean_squared_error: 1.1690 - y2_output_root_mean_squared_error: 2.0638 - val_loss: 14.8038 - val_y1_output_loss: 4.2965 - val_y2_output_loss: 11.2409 - val_y1_output_root_mean_squared_error: 2.0061 - val_y2_output_root_mean_squared_error: 3.2832
# Epoch 75/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.4365 - y1_output_loss: 1.6654 - y2_output_loss: 4.7494 - y1_output_root_mean_squared_error: 1.2961 - y2_output_root_mean_squared_error: 2.1810 - val_loss: 5.7841 - val_y1_output_loss: 1.1306 - val_y2_output_loss: 4.9518 - val_y1_output_root_mean_squared_error: 1.0221 - val_y2_output_root_mean_squared_error: 2.1770
# Epoch 76/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.0318 - y1_output_loss: 1.2441 - y2_output_loss: 3.8023 - y1_output_root_mean_squared_error: 1.1200 - y2_output_root_mean_squared_error: 1.9435 - val_loss: 5.2908 - val_y1_output_loss: 1.5209 - val_y2_output_loss: 3.9854 - val_y1_output_root_mean_squared_error: 1.1859 - val_y2_output_root_mean_squared_error: 1.9709
# Epoch 77/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.2819 - y1_output_loss: 1.0323 - y2_output_loss: 3.2318 - y1_output_root_mean_squared_error: 1.0193 - y2_output_root_mean_squared_error: 1.8008 - val_loss: 6.4075 - val_y1_output_loss: 1.5618 - val_y2_output_loss: 5.2024 - val_y1_output_root_mean_squared_error: 1.1942 - val_y2_output_root_mean_squared_error: 2.2319
# Epoch 78/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7354 - y1_output_loss: 0.9228 - y2_output_loss: 2.8469 - y1_output_root_mean_squared_error: 0.9640 - y2_output_root_mean_squared_error: 1.6751 - val_loss: 6.7605 - val_y1_output_loss: 1.5440 - val_y2_output_loss: 5.4273 - val_y1_output_root_mean_squared_error: 1.2115 - val_y2_output_root_mean_squared_error: 2.3006
# Epoch 79/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.3185 - y1_output_loss: 1.0503 - y2_output_loss: 3.2416 - y1_output_root_mean_squared_error: 1.0287 - y2_output_root_mean_squared_error: 1.8056 - val_loss: 4.1961 - val_y1_output_loss: 1.2708 - val_y2_output_loss: 3.0543 - val_y1_output_root_mean_squared_error: 1.1068 - val_y2_output_root_mean_squared_error: 1.7237
# Epoch 80/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.2281 - y1_output_loss: 1.1012 - y2_output_loss: 3.1474 - y1_output_root_mean_squared_error: 1.0532 - y2_output_root_mean_squared_error: 1.7660 - val_loss: 9.0928 - val_y1_output_loss: 2.6748 - val_y2_output_loss: 6.8021 - val_y1_output_root_mean_squared_error: 1.5852 - val_y2_output_root_mean_squared_error: 2.5651
# Epoch 81/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.3628 - y1_output_loss: 1.1627 - y2_output_loss: 3.1922 - y1_output_root_mean_squared_error: 1.0763 - y2_output_root_mean_squared_error: 1.7901 - val_loss: 5.0934 - val_y1_output_loss: 1.5738 - val_y2_output_loss: 3.6780 - val_y1_output_root_mean_squared_error: 1.2236 - val_y2_output_root_mean_squared_error: 1.8963
# Epoch 82/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.7708 - y1_output_loss: 0.8884 - y2_output_loss: 2.8549 - y1_output_root_mean_squared_error: 0.9450 - y2_output_root_mean_squared_error: 1.6964 - val_loss: 3.1904 - val_y1_output_loss: 0.9506 - val_y2_output_loss: 2.3772 - val_y1_output_root_mean_squared_error: 0.9339 - val_y2_output_root_mean_squared_error: 1.5226
# Epoch 83/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.0688 - y1_output_loss: 0.8959 - y2_output_loss: 3.1476 - y1_output_root_mean_squared_error: 0.9497 - y2_output_root_mean_squared_error: 1.7796 - val_loss: 3.5167 - val_y1_output_loss: 0.8945 - val_y2_output_loss: 2.7581 - val_y1_output_root_mean_squared_error: 0.9158 - val_y2_output_root_mean_squared_error: 1.6365
# Epoch 84/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.5432 - y1_output_loss: 0.8207 - y2_output_loss: 2.6960 - y1_output_root_mean_squared_error: 0.9092 - y2_output_root_mean_squared_error: 1.6482 - val_loss: 4.6894 - val_y1_output_loss: 1.2557 - val_y2_output_loss: 3.6412 - val_y1_output_root_mean_squared_error: 1.0810 - val_y2_output_root_mean_squared_error: 1.8764
# Epoch 85/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.2642 - y1_output_loss: 1.4656 - y2_output_loss: 3.7533 - y1_output_root_mean_squared_error: 1.2152 - y2_output_root_mean_squared_error: 1.9462 - val_loss: 3.3037 - val_y1_output_loss: 0.7668 - val_y2_output_loss: 2.5279 - val_y1_output_root_mean_squared_error: 0.8729 - val_y2_output_root_mean_squared_error: 1.5943
# Epoch 86/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.6735 - y1_output_loss: 1.7111 - y2_output_loss: 4.9271 - y1_output_root_mean_squared_error: 1.3076 - y2_output_root_mean_squared_error: 2.2279 - val_loss: 3.5356 - val_y1_output_loss: 0.7305 - val_y2_output_loss: 2.8626 - val_y1_output_root_mean_squared_error: 0.8395 - val_y2_output_root_mean_squared_error: 1.6825
# Epoch 87/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.0472 - y1_output_loss: 1.0944 - y2_output_loss: 2.9814 - y1_output_root_mean_squared_error: 1.0493 - y2_output_root_mean_squared_error: 1.7164 - val_loss: 15.6243 - val_y1_output_loss: 2.3835 - val_y2_output_loss: 13.8125 - val_y1_output_root_mean_squared_error: 1.4868 - val_y2_output_root_mean_squared_error: 3.6625
# Epoch 88/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.9875 - y1_output_loss: 0.9171 - y2_output_loss: 3.0987 - y1_output_root_mean_squared_error: 0.9510 - y2_output_root_mean_squared_error: 1.7559 - val_loss: 21.8873 - val_y1_output_loss: 8.5038 - val_y2_output_loss: 14.5094 - val_y1_output_root_mean_squared_error: 2.8273 - val_y2_output_root_mean_squared_error: 3.7274
# Epoch 89/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.5099 - y1_output_loss: 1.0541 - y2_output_loss: 3.4432 - y1_output_root_mean_squared_error: 1.0287 - y2_output_root_mean_squared_error: 1.8579 - val_loss: 3.7169 - val_y1_output_loss: 0.7831 - val_y2_output_loss: 3.0436 - val_y1_output_root_mean_squared_error: 0.8559 - val_y2_output_root_mean_squared_error: 1.7275
# Epoch 90/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.2240 - y1_output_loss: 1.0666 - y2_output_loss: 3.1494 - y1_output_root_mean_squared_error: 1.0263 - y2_output_root_mean_squared_error: 1.7806 - val_loss: 4.6736 - val_y1_output_loss: 1.4806 - val_y2_output_loss: 3.1948 - val_y1_output_root_mean_squared_error: 1.2251 - val_y2_output_root_mean_squared_error: 1.7812
# Epoch 91/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.2126 - y1_output_loss: 1.1509 - y2_output_loss: 3.0382 - y1_output_root_mean_squared_error: 1.0760 - y2_output_root_mean_squared_error: 1.7478 - val_loss: 3.6531 - val_y1_output_loss: 1.1432 - val_y2_output_loss: 2.6164 - val_y1_output_root_mean_squared_error: 1.0429 - val_y2_output_root_mean_squared_error: 1.6017
# Epoch 92/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1832 - y1_output_loss: 0.7445 - y2_output_loss: 2.4381 - y1_output_root_mean_squared_error: 0.8667 - y2_output_root_mean_squared_error: 1.5595 - val_loss: 3.2149 - val_y1_output_loss: 0.8741 - val_y2_output_loss: 2.4325 - val_y1_output_root_mean_squared_error: 0.9137 - val_y2_output_root_mean_squared_error: 1.5428
# Epoch 93/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.5279 - y1_output_loss: 1.1202 - y2_output_loss: 3.3852 - y1_output_root_mean_squared_error: 1.0629 - y2_output_root_mean_squared_error: 1.8434 - val_loss: 3.0911 - val_y1_output_loss: 0.9497 - val_y2_output_loss: 2.2335 - val_y1_output_root_mean_squared_error: 0.9489 - val_y2_output_root_mean_squared_error: 1.4801
# Epoch 94/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5797 - y1_output_loss: 0.8488 - y2_output_loss: 2.7023 - y1_output_root_mean_squared_error: 0.9243 - y2_output_root_mean_squared_error: 1.6509 - val_loss: 3.8768 - val_y1_output_loss: 1.1422 - val_y2_output_loss: 2.8713 - val_y1_output_root_mean_squared_error: 1.0276 - val_y2_output_root_mean_squared_error: 1.6795
# Epoch 95/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.4637 - y1_output_loss: 1.0502 - y2_output_loss: 3.3811 - y1_output_root_mean_squared_error: 1.0286 - y2_output_root_mean_squared_error: 1.8454 - val_loss: 3.9835 - val_y1_output_loss: 1.2501 - val_y2_output_loss: 2.7306 - val_y1_output_root_mean_squared_error: 1.1196 - val_y2_output_root_mean_squared_error: 1.6523
# Epoch 96/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1822 - y1_output_loss: 0.6959 - y2_output_loss: 2.4844 - y1_output_root_mean_squared_error: 0.8283 - y2_output_root_mean_squared_error: 1.5799 - val_loss: 3.9008 - val_y1_output_loss: 1.1248 - val_y2_output_loss: 2.7822 - val_y1_output_root_mean_squared_error: 1.0675 - val_y2_output_root_mean_squared_error: 1.6617
# Epoch 97/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.4224 - y1_output_loss: 0.7515 - y2_output_loss: 2.6584 - y1_output_root_mean_squared_error: 0.8685 - y2_output_root_mean_squared_error: 1.6335 - val_loss: 2.7251 - val_y1_output_loss: 0.6570 - val_y2_output_loss: 2.0855 - val_y1_output_root_mean_squared_error: 0.7958 - val_y2_output_root_mean_squared_error: 1.4463
# Epoch 98/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1943 - y1_output_loss: 0.7334 - y2_output_loss: 2.4948 - y1_output_root_mean_squared_error: 0.8586 - y2_output_root_mean_squared_error: 1.5675 - val_loss: 7.5232 - val_y1_output_loss: 0.8388 - val_y2_output_loss: 6.7919 - val_y1_output_root_mean_squared_error: 0.9143 - val_y2_output_root_mean_squared_error: 2.5860
# Epoch 99/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0424 - y1_output_loss: 0.6711 - y2_output_loss: 2.3583 - y1_output_root_mean_squared_error: 0.8195 - y2_output_root_mean_squared_error: 1.5397 - val_loss: 4.3693 - val_y1_output_loss: 0.7175 - val_y2_output_loss: 3.6902 - val_y1_output_root_mean_squared_error: 0.8326 - val_y2_output_root_mean_squared_error: 1.9173
# Epoch 100/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.0969 - y1_output_loss: 0.6262 - y2_output_loss: 2.4837 - y1_output_root_mean_squared_error: 0.7917 - y2_output_root_mean_squared_error: 1.5717 - val_loss: 7.2186 - val_y1_output_loss: 0.9314 - val_y2_output_loss: 6.4470 - val_y1_output_root_mean_squared_error: 0.9557 - val_y2_output_root_mean_squared_error: 2.5110
# Epoch 101/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.0464 - y1_output_loss: 1.0167 - y2_output_loss: 3.0429 - y1_output_root_mean_squared_error: 1.0126 - y2_output_root_mean_squared_error: 1.7381 - val_loss: 3.3223 - val_y1_output_loss: 0.8550 - val_y2_output_loss: 2.4240 - val_y1_output_root_mean_squared_error: 0.9264 - val_y2_output_root_mean_squared_error: 1.5698
# Epoch 102/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.2509 - y1_output_loss: 0.7917 - y2_output_loss: 3.4396 - y1_output_root_mean_squared_error: 0.8824 - y2_output_root_mean_squared_error: 1.8634 - val_loss: 2.9709 - val_y1_output_loss: 0.7307 - val_y2_output_loss: 2.2869 - val_y1_output_root_mean_squared_error: 0.8346 - val_y2_output_root_mean_squared_error: 1.5081
# Epoch 103/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.0854 - y1_output_loss: 1.1420 - y2_output_loss: 2.9608 - y1_output_root_mean_squared_error: 1.0621 - y2_output_root_mean_squared_error: 1.7197 - val_loss: 6.1964 - val_y1_output_loss: 2.0713 - val_y2_output_loss: 4.3282 - val_y1_output_root_mean_squared_error: 1.4125 - val_y2_output_root_mean_squared_error: 2.0497
# Epoch 104/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7778 - y1_output_loss: 0.5792 - y2_output_loss: 2.1766 - y1_output_root_mean_squared_error: 0.7646 - y2_output_root_mean_squared_error: 1.4809 - val_loss: 3.1741 - val_y1_output_loss: 0.7001 - val_y2_output_loss: 2.5026 - val_y1_output_root_mean_squared_error: 0.8366 - val_y2_output_root_mean_squared_error: 1.5730
# Epoch 105/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2239 - y1_output_loss: 0.7146 - y2_output_loss: 2.4991 - y1_output_root_mean_squared_error: 0.8436 - y2_output_root_mean_squared_error: 1.5850 - val_loss: 4.3136 - val_y1_output_loss: 1.3758 - val_y2_output_loss: 2.9197 - val_y1_output_root_mean_squared_error: 1.1690 - val_y2_output_root_mean_squared_error: 1.7167
# Epoch 106/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.6780 - y1_output_loss: 0.7591 - y2_output_loss: 2.9174 - y1_output_root_mean_squared_error: 0.8753 - y2_output_root_mean_squared_error: 1.7064 - val_loss: 3.0894 - val_y1_output_loss: 0.7754 - val_y2_output_loss: 2.2814 - val_y1_output_root_mean_squared_error: 0.8851 - val_y2_output_root_mean_squared_error: 1.5185
# Epoch 107/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.5768 - y1_output_loss: 0.6529 - y2_output_loss: 1.9318 - y1_output_root_mean_squared_error: 0.8067 - y2_output_root_mean_squared_error: 1.3878 - val_loss: 2.4711 - val_y1_output_loss: 0.6340 - val_y2_output_loss: 1.8192 - val_y1_output_root_mean_squared_error: 0.7955 - val_y2_output_root_mean_squared_error: 1.3558
# Epoch 108/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1630 - y1_output_loss: 0.6574 - y2_output_loss: 2.4829 - y1_output_root_mean_squared_error: 0.8137 - y2_output_root_mean_squared_error: 1.5814 - val_loss: 4.5437 - val_y1_output_loss: 1.6617 - val_y2_output_loss: 2.9119 - val_y1_output_root_mean_squared_error: 1.2642 - val_y2_output_root_mean_squared_error: 1.7162
# Epoch 109/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.1191 - y1_output_loss: 0.9273 - y2_output_loss: 3.1578 - y1_output_root_mean_squared_error: 0.9668 - y2_output_root_mean_squared_error: 1.7845 - val_loss: 2.4750 - val_y1_output_loss: 0.6653 - val_y2_output_loss: 1.7736 - val_y1_output_root_mean_squared_error: 0.8200 - val_y2_output_root_mean_squared_error: 1.3426
# Epoch 110/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.3665 - y1_output_loss: 0.7594 - y2_output_loss: 2.6116 - y1_output_root_mean_squared_error: 0.8741 - y2_output_root_mean_squared_error: 1.6132 - val_loss: 5.2248 - val_y1_output_loss: 1.8103 - val_y2_output_loss: 3.4472 - val_y1_output_root_mean_squared_error: 1.3286 - val_y2_output_root_mean_squared_error: 1.8600
# Epoch 111/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.3963 - y1_output_loss: 0.8165 - y2_output_loss: 2.5990 - y1_output_root_mean_squared_error: 0.9068 - y2_output_root_mean_squared_error: 1.6044 - val_loss: 4.4063 - val_y1_output_loss: 0.8267 - val_y2_output_loss: 3.6207 - val_y1_output_root_mean_squared_error: 0.9157 - val_y2_output_root_mean_squared_error: 1.8888
# Epoch 112/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5852 - y1_output_loss: 0.6018 - y2_output_loss: 1.9705 - y1_output_root_mean_squared_error: 0.7778 - y2_output_root_mean_squared_error: 1.4072 - val_loss: 3.4906 - val_y1_output_loss: 0.9335 - val_y2_output_loss: 2.5973 - val_y1_output_root_mean_squared_error: 0.9347 - val_y2_output_root_mean_squared_error: 1.6177
# Epoch 113/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8843 - y1_output_loss: 0.9566 - y2_output_loss: 2.9149 - y1_output_root_mean_squared_error: 0.9826 - y2_output_root_mean_squared_error: 1.7085 - val_loss: 4.1063 - val_y1_output_loss: 0.8150 - val_y2_output_loss: 3.2734 - val_y1_output_root_mean_squared_error: 0.9092 - val_y2_output_root_mean_squared_error: 1.8110
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9343 - y1_output_loss: 0.7198 - y2_output_loss: 2.2181 - y1_output_root_mean_squared_error: 0.8393 - y2_output_root_mean_squared_error: 1.4932 - val_loss: 4.2780 - val_y1_output_loss: 1.3049 - val_y2_output_loss: 3.0959 - val_y1_output_root_mean_squared_error: 1.1206 - val_y2_output_root_mean_squared_error: 1.7385
# Epoch 115/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.3988 - y1_output_loss: 1.6911 - y2_output_loss: 4.6838 - y1_output_root_mean_squared_error: 1.3015 - y2_output_root_mean_squared_error: 2.1691 - val_loss: 5.3936 - val_y1_output_loss: 1.8969 - val_y2_output_loss: 3.6292 - val_y1_output_root_mean_squared_error: 1.3429 - val_y2_output_root_mean_squared_error: 1.8948
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9353 - y1_output_loss: 0.6980 - y2_output_loss: 2.2341 - y1_output_root_mean_squared_error: 0.8263 - y2_output_root_mean_squared_error: 1.5008 - val_loss: 2.5264 - val_y1_output_loss: 0.7381 - val_y2_output_loss: 1.7516 - val_y1_output_root_mean_squared_error: 0.8692 - val_y2_output_root_mean_squared_error: 1.3308
# Epoch 117/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.1868 - y1_output_loss: 0.9847 - y2_output_loss: 3.1823 - y1_output_root_mean_squared_error: 0.9946 - y2_output_root_mean_squared_error: 1.7882 - val_loss: 2.7781 - val_y1_output_loss: 0.6700 - val_y2_output_loss: 2.1213 - val_y1_output_root_mean_squared_error: 0.8026 - val_y2_output_root_mean_squared_error: 1.4608
# Epoch 118/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.3641 - y1_output_loss: 0.7734 - y2_output_loss: 2.5779 - y1_output_root_mean_squared_error: 0.8804 - y2_output_root_mean_squared_error: 1.6090 - val_loss: 6.5466 - val_y1_output_loss: 1.1147 - val_y2_output_loss: 5.5402 - val_y1_output_root_mean_squared_error: 1.0243 - val_y2_output_root_mean_squared_error: 2.3447
# Epoch 119/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0608 - y1_output_loss: 0.7278 - y2_output_loss: 2.3380 - y1_output_root_mean_squared_error: 0.8464 - y2_output_root_mean_squared_error: 1.5311 - val_loss: 4.8605 - val_y1_output_loss: 1.1399 - val_y2_output_loss: 3.7722 - val_y1_output_root_mean_squared_error: 1.0721 - val_y2_output_root_mean_squared_error: 1.9264
# Epoch 120/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.4146 - y1_output_loss: 0.6134 - y2_output_loss: 1.8292 - y1_output_root_mean_squared_error: 0.7827 - y2_output_root_mean_squared_error: 1.3424 - val_loss: 2.8570 - val_y1_output_loss: 0.9579 - val_y2_output_loss: 1.9051 - val_y1_output_root_mean_squared_error: 0.9659 - val_y2_output_root_mean_squared_error: 1.3871
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5600 - y1_output_loss: 0.1607 - y2_output_loss: 0.3970 - y1_output_root_mean_squared_error: 0.4023 - y2_output_root_mean_squared_error: 0.6310 - val_loss: 2.1966 - val_y1_output_loss: 0.5302 - val_y2_output_loss: 1.7462 - val_y1_output_root_mean_squared_error: 0.7240 - val_y2_output_root_mean_squared_error: 1.2932
# Epoch 462/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4044 - y1_output_loss: 0.1326 - y2_output_loss: 0.2718 - y1_output_root_mean_squared_error: 0.3647 - y2_output_root_mean_squared_error: 0.5209 - val_loss: 0.9406 - val_y1_output_loss: 0.2616 - val_y2_output_loss: 0.6897 - val_y1_output_root_mean_squared_error: 0.5051 - val_y2_output_root_mean_squared_error: 0.8279
# Epoch 463/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3592 - y1_output_loss: 0.1171 - y2_output_loss: 0.2471 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.4909 - val_loss: 2.0871 - val_y1_output_loss: 0.2857 - val_y2_output_loss: 1.7801 - val_y1_output_root_mean_squared_error: 0.5177 - val_y2_output_root_mean_squared_error: 1.3487
# Epoch 464/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5956 - y1_output_loss: 0.1624 - y2_output_loss: 0.4308 - y1_output_root_mean_squared_error: 0.4036 - y2_output_root_mean_squared_error: 0.6578 - val_loss: 0.7388 - val_y1_output_loss: 0.2486 - val_y2_output_loss: 0.5022 - val_y1_output_root_mean_squared_error: 0.4823 - val_y2_output_root_mean_squared_error: 0.7114
# Epoch 465/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3516 - y1_output_loss: 0.1104 - y2_output_loss: 0.2399 - y1_output_root_mean_squared_error: 0.3334 - y2_output_root_mean_squared_error: 0.4903 - val_loss: 0.8880 - val_y1_output_loss: 0.3406 - val_y2_output_loss: 0.5643 - val_y1_output_root_mean_squared_error: 0.5629 - val_y2_output_root_mean_squared_error: 0.7558
# Epoch 466/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3683 - y1_output_loss: 0.1280 - y2_output_loss: 0.2463 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.4947 - val_loss: 1.3606 - val_y1_output_loss: 0.4613 - val_y2_output_loss: 0.9055 - val_y1_output_root_mean_squared_error: 0.6587 - val_y2_output_root_mean_squared_error: 0.9626
# Epoch 467/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3812 - y1_output_loss: 0.1317 - y2_output_loss: 0.2490 - y1_output_root_mean_squared_error: 0.3620 - y2_output_root_mean_squared_error: 0.5001 - val_loss: 0.9290 - val_y1_output_loss: 0.2607 - val_y2_output_loss: 0.6702 - val_y1_output_root_mean_squared_error: 0.4914 - val_y2_output_root_mean_squared_error: 0.8292
# Epoch 468/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3889 - y1_output_loss: 0.1259 - y2_output_loss: 0.2604 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.5120 - val_loss: 0.7744 - val_y1_output_loss: 0.2516 - val_y2_output_loss: 0.5468 - val_y1_output_root_mean_squared_error: 0.4793 - val_y2_output_root_mean_squared_error: 0.7380
# Epoch 469/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4653 - y1_output_loss: 0.1466 - y2_output_loss: 0.3158 - y1_output_root_mean_squared_error: 0.3842 - y2_output_root_mean_squared_error: 0.5636 - val_loss: 0.7311 - val_y1_output_loss: 0.2113 - val_y2_output_loss: 0.5234 - val_y1_output_root_mean_squared_error: 0.4472 - val_y2_output_root_mean_squared_error: 0.7288
# Epoch 470/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3784 - y1_output_loss: 0.1133 - y2_output_loss: 0.2645 - y1_output_root_mean_squared_error: 0.3367 - y2_output_root_mean_squared_error: 0.5148 - val_loss: 1.0655 - val_y1_output_loss: 0.2693 - val_y2_output_loss: 0.7966 - val_y1_output_root_mean_squared_error: 0.5015 - val_y2_output_root_mean_squared_error: 0.9022
# Epoch 471/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3670 - y1_output_loss: 0.1280 - y2_output_loss: 0.2436 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.4890 - val_loss: 1.6937 - val_y1_output_loss: 0.5917 - val_y2_output_loss: 1.1377 - val_y1_output_root_mean_squared_error: 0.7428 - val_y2_output_root_mean_squared_error: 1.0686
# Epoch 472/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4397 - y1_output_loss: 0.1442 - y2_output_loss: 0.2935 - y1_output_root_mean_squared_error: 0.3796 - y2_output_root_mean_squared_error: 0.5437 - val_loss: 0.9017 - val_y1_output_loss: 0.2927 - val_y2_output_loss: 0.6167 - val_y1_output_root_mean_squared_error: 0.5368 - val_y2_output_root_mean_squared_error: 0.7833
# Epoch 473/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4034 - y1_output_loss: 0.1373 - y2_output_loss: 0.2631 - y1_output_root_mean_squared_error: 0.3723 - y2_output_root_mean_squared_error: 0.5146 - val_loss: 0.7079 - val_y1_output_loss: 0.1913 - val_y2_output_loss: 0.5285 - val_y1_output_root_mean_squared_error: 0.4258 - val_y2_output_root_mean_squared_error: 0.7257
# Epoch 474/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3130 - y1_output_loss: 0.1138 - y2_output_loss: 0.1999 - y1_output_root_mean_squared_error: 0.3379 - y2_output_root_mean_squared_error: 0.4459 - val_loss: 0.8933 - val_y1_output_loss: 0.2844 - val_y2_output_loss: 0.6221 - val_y1_output_root_mean_squared_error: 0.5143 - val_y2_output_root_mean_squared_error: 0.7930
# Epoch 475/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5566 - y1_output_loss: 0.1525 - y2_output_loss: 0.3990 - y1_output_root_mean_squared_error: 0.3923 - y2_output_root_mean_squared_error: 0.6346 - val_loss: 0.7743 - val_y1_output_loss: 0.2506 - val_y2_output_loss: 0.5329 - val_y1_output_root_mean_squared_error: 0.4825 - val_y2_output_root_mean_squared_error: 0.7358
# Epoch 476/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3701 - y1_output_loss: 0.1184 - y2_output_loss: 0.2529 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.5026 - val_loss: 1.0048 - val_y1_output_loss: 0.3430 - val_y2_output_loss: 0.6707 - val_y1_output_root_mean_squared_error: 0.5622 - val_y2_output_root_mean_squared_error: 0.8299
# Epoch 477/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4159 - y1_output_loss: 0.1383 - y2_output_loss: 0.2810 - y1_output_root_mean_squared_error: 0.3694 - y2_output_root_mean_squared_error: 0.5286 - val_loss: 1.7405 - val_y1_output_loss: 0.5325 - val_y2_output_loss: 1.2011 - val_y1_output_root_mean_squared_error: 0.7239 - val_y2_output_root_mean_squared_error: 1.1030
# Epoch 478/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4507 - y1_output_loss: 0.1368 - y2_output_loss: 0.3119 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.5603 - val_loss: 0.8418 - val_y1_output_loss: 0.2648 - val_y2_output_loss: 0.5876 - val_y1_output_root_mean_squared_error: 0.5018 - val_y2_output_root_mean_squared_error: 0.7681
# Epoch 479/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3945 - y1_output_loss: 0.1329 - y2_output_loss: 0.2625 - y1_output_root_mean_squared_error: 0.3656 - y2_output_root_mean_squared_error: 0.5107 - val_loss: 1.0778 - val_y1_output_loss: 0.2109 - val_y2_output_loss: 0.9077 - val_y1_output_root_mean_squared_error: 0.4489 - val_y2_output_root_mean_squared_error: 0.9361
# Epoch 480/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5659 - y1_output_loss: 0.1573 - y2_output_loss: 0.4053 - y1_output_root_mean_squared_error: 0.3984 - y2_output_root_mean_squared_error: 0.6381 - val_loss: 0.8415 - val_y1_output_loss: 0.3041 - val_y2_output_loss: 0.5608 - val_y1_output_root_mean_squared_error: 0.5300 - val_y2_output_root_mean_squared_error: 0.7487
# Epoch 481/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3494 - y1_output_loss: 0.1025 - y2_output_loss: 0.2451 - y1_output_root_mean_squared_error: 0.3215 - y2_output_root_mean_squared_error: 0.4961 - val_loss: 0.6824 - val_y1_output_loss: 0.1886 - val_y2_output_loss: 0.5001 - val_y1_output_root_mean_squared_error: 0.4231 - val_y2_output_root_mean_squared_error: 0.7095
# Epoch 482/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5270 - y1_output_loss: 0.1338 - y2_output_loss: 0.3932 - y1_output_root_mean_squared_error: 0.3670 - y2_output_root_mean_squared_error: 0.6264 - val_loss: 1.2778 - val_y1_output_loss: 0.2257 - val_y2_output_loss: 1.1059 - val_y1_output_root_mean_squared_error: 0.4698 - val_y2_output_root_mean_squared_error: 1.0281
# Epoch 483/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3585 - y1_output_loss: 0.1179 - y2_output_loss: 0.2407 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.4913 - val_loss: 0.9190 - val_y1_output_loss: 0.2927 - val_y2_output_loss: 0.6423 - val_y1_output_root_mean_squared_error: 0.5323 - val_y2_output_root_mean_squared_error: 0.7973
# Epoch 484/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2984 - y1_output_loss: 0.1151 - y2_output_loss: 0.1818 - y1_output_root_mean_squared_error: 0.3407 - y2_output_root_mean_squared_error: 0.4270 - val_loss: 0.7828 - val_y1_output_loss: 0.2012 - val_y2_output_loss: 0.5789 - val_y1_output_root_mean_squared_error: 0.4377 - val_y2_output_root_mean_squared_error: 0.7689
# Epoch 485/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3393 - y1_output_loss: 0.1083 - y2_output_loss: 0.2291 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.4807 - val_loss: 0.9002 - val_y1_output_loss: 0.2782 - val_y2_output_loss: 0.6245 - val_y1_output_root_mean_squared_error: 0.5156 - val_y2_output_root_mean_squared_error: 0.7964
# Epoch 486/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3549 - y1_output_loss: 0.1143 - y2_output_loss: 0.2387 - y1_output_root_mean_squared_error: 0.3383 - y2_output_root_mean_squared_error: 0.4903 - val_loss: 0.6916 - val_y1_output_loss: 0.2233 - val_y2_output_loss: 0.4789 - val_y1_output_root_mean_squared_error: 0.4587 - val_y2_output_root_mean_squared_error: 0.6937
# Epoch 487/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3335 - y1_output_loss: 0.1170 - y2_output_loss: 0.2160 - y1_output_root_mean_squared_error: 0.3430 - y2_output_root_mean_squared_error: 0.4646 - val_loss: 0.8689 - val_y1_output_loss: 0.2091 - val_y2_output_loss: 0.6580 - val_y1_output_root_mean_squared_error: 0.4394 - val_y2_output_root_mean_squared_error: 0.8221
# Epoch 488/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4429 - y1_output_loss: 0.1505 - y2_output_loss: 0.2904 - y1_output_root_mean_squared_error: 0.3897 - y2_output_root_mean_squared_error: 0.5395 - val_loss: 0.7915 - val_y1_output_loss: 0.2738 - val_y2_output_loss: 0.5293 - val_y1_output_root_mean_squared_error: 0.5066 - val_y2_output_root_mean_squared_error: 0.7313
# Epoch 489/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3871 - y1_output_loss: 0.1454 - y2_output_loss: 0.2386 - y1_output_root_mean_squared_error: 0.3830 - y2_output_root_mean_squared_error: 0.4904 - val_loss: 0.7720 - val_y1_output_loss: 0.2036 - val_y2_output_loss: 0.5719 - val_y1_output_root_mean_squared_error: 0.4382 - val_y2_output_root_mean_squared_error: 0.7616
# Epoch 490/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3305 - y1_output_loss: 0.1209 - y2_output_loss: 0.2135 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.4598 - val_loss: 1.3914 - val_y1_output_loss: 0.4392 - val_y2_output_loss: 0.9945 - val_y1_output_root_mean_squared_error: 0.6552 - val_y2_output_root_mean_squared_error: 0.9809
# Epoch 491/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3372 - y1_output_loss: 0.1256 - y2_output_loss: 0.2229 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.4632 - val_loss: 1.5928 - val_y1_output_loss: 0.2907 - val_y2_output_loss: 1.3630 - val_y1_output_root_mean_squared_error: 0.5403 - val_y2_output_root_mean_squared_error: 1.1405
# Epoch 492/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4118 - y1_output_loss: 0.1279 - y2_output_loss: 0.2804 - y1_output_root_mean_squared_error: 0.3591 - y2_output_root_mean_squared_error: 0.5319 - val_loss: 0.7342 - val_y1_output_loss: 0.2181 - val_y2_output_loss: 0.5216 - val_y1_output_root_mean_squared_error: 0.4555 - val_y2_output_root_mean_squared_error: 0.7258
# Epoch 493/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3392 - y1_output_loss: 0.1194 - y2_output_loss: 0.2184 - y1_output_root_mean_squared_error: 0.3460 - y2_output_root_mean_squared_error: 0.4685 - val_loss: 0.6965 - val_y1_output_loss: 0.1970 - val_y2_output_loss: 0.5095 - val_y1_output_root_mean_squared_error: 0.4267 - val_y2_output_root_mean_squared_error: 0.7172
# Epoch 494/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3778 - y1_output_loss: 0.1275 - y2_output_loss: 0.2477 - y1_output_root_mean_squared_error: 0.3583 - y2_output_root_mean_squared_error: 0.4994 - val_loss: 0.7498 - val_y1_output_loss: 0.1961 - val_y2_output_loss: 0.5527 - val_y1_output_root_mean_squared_error: 0.4319 - val_y2_output_root_mean_squared_error: 0.7505
# Epoch 495/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3839 - y1_output_loss: 0.1202 - y2_output_loss: 0.2618 - y1_output_root_mean_squared_error: 0.3475 - y2_output_root_mean_squared_error: 0.5129 - val_loss: 0.8585 - val_y1_output_loss: 0.2432 - val_y2_output_loss: 0.6221 - val_y1_output_root_mean_squared_error: 0.4831 - val_y2_output_root_mean_squared_error: 0.7906
# Epoch 496/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3825 - y1_output_loss: 0.1268 - y2_output_loss: 0.2548 - y1_output_root_mean_squared_error: 0.3570 - y2_output_root_mean_squared_error: 0.5051 - val_loss: 0.8139 - val_y1_output_loss: 0.2668 - val_y2_output_loss: 0.5478 - val_y1_output_root_mean_squared_error: 0.5041 - val_y2_output_root_mean_squared_error: 0.7482
# Epoch 497/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3163 - y1_output_loss: 0.1035 - y2_output_loss: 0.2146 - y1_output_root_mean_squared_error: 0.3217 - y2_output_root_mean_squared_error: 0.4614 - val_loss: 0.8657 - val_y1_output_loss: 0.2336 - val_y2_output_loss: 0.6322 - val_y1_output_root_mean_squared_error: 0.4691 - val_y2_output_root_mean_squared_error: 0.8035
# Epoch 498/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4041 - y1_output_loss: 0.1368 - y2_output_loss: 0.2796 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5186 - val_loss: 1.8678 - val_y1_output_loss: 0.2850 - val_y2_output_loss: 1.6518 - val_y1_output_root_mean_squared_error: 0.5299 - val_y2_output_root_mean_squared_error: 1.2598
# Epoch 499/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4089 - y1_output_loss: 0.1332 - y2_output_loss: 0.3007 - y1_output_root_mean_squared_error: 0.3643 - y2_output_root_mean_squared_error: 0.5256 - val_loss: 1.4734 - val_y1_output_loss: 0.4473 - val_y2_output_loss: 1.0144 - val_y1_output_root_mean_squared_error: 0.6630 - val_y2_output_root_mean_squared_error: 1.0168
# Epoch 500/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4112 - y1_output_loss: 0.1311 - y2_output_loss: 0.2783 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.5283 - val_loss: 0.7536 - val_y1_output_loss: 0.2140 - val_y2_output_loss: 0.5607 - val_y1_output_root_mean_squared_error: 0.4535 - val_y2_output_root_mean_squared_error: 0.7403

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 30us/sample - loss: 0.7536 - y1_output_loss: 0.2078 - y2_output_loss: 0.5479 - y1_output_root_mean_squared_error: 0.4535 - y2_output_root_mean_squared_error: 0.7403
# Loss = 0.7536452048784726, Y1_loss = 0.20781919360160828, Y1_mse = 0.45345839858055115, Y2_loss = 0.5478577613830566, Y2_mse = 0.7402842044830322

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
